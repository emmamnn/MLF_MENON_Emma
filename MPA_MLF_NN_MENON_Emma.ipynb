# %% [markdown]
# # MPA-MLF, Lab 5 - Feedforward Neural Networks

# %% [markdown]
# These exercises are focused on dealing with neural networks. It is strongly recommended to use google collab for these pc labs. Why? Google collab offers a free GPU capacity to train machine learning models. Training NN on GPU can drastically speed up the training process. You can turn on the GPU accelerator in: Runtime -> Change runtime type -> GPU,

# %% [markdown]
# ## The basic terminology

# %% [markdown]
# ### Neural Networks

# %% [markdown]
# Think of a neural network as a complex web of neurons (or nodes) that are interconnected to process information, similar to how the human brain works. Each neuron in this network can receive inputs, process them, and pass on the output to other neurons. The goal of a neural network is to transform the inputs (e.g., images, texts, numbers) into a desired output (e.g., identifying what's in an image, translating text, etc.).

# %% [markdown]
# ![title](img/network.png)

# %% [markdown]
# ### Layers

# %% [markdown]
# A neural network is made up of layers: the input layer (where the data enters the network), one or more hidden layers (where most of the processing happens), and the output layer (where the final prediction is made). You can think of each layer as a filter that increasingly refines the information as it passes through the network. In our case, we will discuss feedforward, fully-connected neural networks. Fully connected means that every neuron in layer *n* is connected by a weighted connection with all neurons in the layers *n+1*. Feedforward means that data are passed in one direction only, there are no reccurent connections (feedback loops) exist.

# %% [markdown]
# ![title](img/Neural_network.png)

# %% [markdown]
# ### Neuron

# %% [markdown]
# A neuron, or node, is the basic unit of a neural network. It receives input, applies a weight (significance) to that input, adds a bias (a constant value to ensure the neuron activates correctly), and then uses an activation function to determine whether and how strongly to pass its signal to the next layer. Each neuron contributes to the network's ability to make accurate predictions or decisions.|

# %% [markdown]
# ![title](img/neuron.png)

# %% [markdown]
# ### Neuron in the input layer

# %% [markdown]
# In the input layer the input neurons are composed of identity only, that means everying that comes to the input comes directly to the output

# %% [markdown]
# ### Training

# %% [markdown]
# Training a neural network involves feeding it with data for which the correct output is known, allowing the network to adjust its weights and biases to minimize the difference between its predictions and the actual truths. This process is repeated numerous times with many data examples.

# %% [markdown]
# ### Loss Function

# %% [markdown]
# A loss function measures how well the neural network is performing, meaning how close or far its predictions are from the actual values. The goal of training is to minimize this loss, or error, making the network's predictions as accurate as possible.

# %% [markdown]
# ## Exercise 1 - XOR problem

# %% [markdown]
# During the last lecture, we saw that the single perceptron model with a step function could be used only for solving linearly-separable classification problems. Because of that, a single perceptron can not be trained to be able to behave like an XOR gate. To approximate the XOR gate using a neural network, we need to use the following structure:

# %% [markdown]
# ![nn.png](data:image/png;base64,...)

# %% [markdown]
# The above structure contains three layers: two neurons in the input layer (blue), two in the hidden layer and one in the output layer (yellow). The input layer represents the identity functions (the outputs are equal to the inputs)

# %% [markdown]
# We will use *Keras* API to build and train our neural network. Keras is an open-source neural network library written in Python. It is designed to enable fast experimentation with deep neural networks and provides a high-level API for building and training neural networks.

# %% [markdown]
# ### 0. First import libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. prepare data

# %% [markdown]
# In this part, the task would be to prepade our dataset, basically it is the logic table for *XOR* function

# %%
X = [[0, 0], [0, 1], [1, 0], [1, 1]]
y = [0, 1, 1, 0]

# %%
#convert X and y to NumPy arrays
X=np.array([[0,0], [0,1],[1,0], [1,1]])
y=np.array([0,1,1,0])

# %% [markdown]
# ### 2. Creating the model

# %% [markdown]
# To create a model of NN that is in the picture above, run the following cell

# %%
model = Sequential()
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# **Sequential** is a model type used in Keras for building feedforward neural networks. It is called "sequential" because the layers are stacked sequentially on top of each other, and the output of one layer is passed as input to the next layer.
#
# To create a sequential model, instantiate a Sequential object and then add layers to it using the **add()** method. There are many layers that Keras offers. We will use *Dense layer*
#
# **Dense layer** represents a fully connected layer, which means that every neuron in the layer is connected to every neuron in the previous layer. In each layer, we will specify an activation function and the number of neurons that layer contains. The input layer is not defined as a dense layer, but instead of that, we will specify the *input_dim* parameter in the layer that follows the input layer. *input_dim* parameter specifies the number of neurons in the input layer

# %% [markdown]
# ### 3. Compile the model

# %% [markdown]
# To compile yor model run:

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# **keras.complile()** is used to configure the learning process before training the model.
# We need to specify 3 parameters:
# - *loss*, *optimizer* and *metrics*
#
# - as our loss function (error function/objective function), we will choose *binary_crossentropy* - loss function often used for binary classification
#
# - *optimizer* is optimization algorithm used for optimizing weights in our training process, we will choose *stochastic gradient descent*
#
# - *metrics* is metric user for model evaluation

# %% [markdown]
# ### 4. Model training

# %% [markdown]
# In the lecture, we talked about training the Multi-layer perceptron. The training process consists of the following steps:
#
# 1. Weight initialization
# 2. Forward Propagation
# 3. Compute Loss
# 4. Backpropagation
# 5. Update Weights
# 6. Repeat 2->6 until maximum epochs are reached
#
# When training a machine learning model, the training data is usually divided into batches (parts), and the model updates its weights after processing each batch. The batch size determines how many training examples are included in each batch.
#
# For example, we have 10,000 training examples and a batch size of 100. In this case, the training data would be divided into 100 batches of 100 examples each. During training, the model would process each batch, calculate the loss or error, and update its weights based on the average of the errors in that batch. In other words, if we batch equal to 1. we will update the weights 10 000 times. If we have batch size == 100, we will update the weights only 100 times

# %% [markdown]
# To train your model, run the following line of the code:

# %%
history = model.fit(X, y, epochs=2000, batch_size=1, verbose=0)

# %% [markdown]
# the method **.fit()**, is used to train the model. We can see that it takes several input parameters:
#  - *X* - input data
#  - *y* - label for the input data
#  - *epochs* number of training epochs (iterations)
#  - *batch_size* - number of samples in each batch
#  - *verbose* - set verbose parameter to see the progress of loss and metrics during the training epochs
#
# These are not the only parameters the .fit() method can take. Check official documentation: https://keras.io/api/models/model_training_apis/
#
# We will set the output of our .fit() function to variable *history*, where the loss and other metrics defined above in the .compile() function during the training are saved.

# %% [markdown]
# ### 5. Model evaluation

# %% [markdown]
# Out training process is finished. To evaluate the performance of our model on test data, tun the following cell of the code:

# %%
loss, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 75.00

# %% [markdown]
# ### 6. Model predictions

# %%
for id_x, data_sample in enumerate(X):
  data_sample=np.array(data_sample).reshape(1,-1)
  prediction = model.predict([data_sample])
  print(f"Data sample is {data_sample}, prediction from model {prediction}, ground_truth {y[id_x]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Data sample is [[0 0]], prediction from model [[0.00177294]], ground_truth 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=('Tensor(shape=(1, 2))',)
#   warnings.warn(msg)
# Data sample is [[0 1]], prediction from model [[0.99829227]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Data sample is [[1 0]], prediction from model [[0.4901696]], ground_truth 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Data sample is [[1 1]], prediction from model [[0.4915949]], ground_truth 0

# %% [markdown]
# ### 7. Display loss function during the training process and acuracy

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.xlabel('n epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### TASK:
#
# In this part of the exercise, the task would be to play around with the code above to see the influence of hyperparameters.
#
# As we know from the lecture, neural networks contain two types of parameters:
#   1. **Learnable parameters** - *weights* and *biases*. these parameters are adjusted in the training process.
#   2. **Non-learnable parameters (hyperparameters)** - learning_rate, number_of_neurons, number_of_layers, number_of_epochs, type of activation functions in the neurons.., basically any user-defined setting is considered to be hyperparameter
#
#
# Change the following parameters:
# - number of epochs
# - learning_rate
# - activation functions in layers,
# - batch_size,
# - verbose,
# - number of neurons in the hidden layer
#
# Moreover, see the influence on the training process and results.
#
# **Note: Every time we change some hyper-parameters, do not forget to compile the model, to initialize the learnable parameters again**

# %% [markdown]
# *   **Epochs** : number of iteration --> more precise but takes more time
# *   If the **learning rate** increase, it will be faster but we may skip the minimum of the loss function
# * **batch_size** : number of input we give to the NN before updating the weight. If small it means it will change frenquently so it's not very stable. Making it bigger may be best so it will be more stable. In our case, it is a simple case so we put one to make it faster.
# * **nb of neurons in the hidden layer** : hidden layer to solve more complex problem. We need to find the balance because if we increase the nb of neurons it means the NN will be more powerful but it will be overfitting. If less it will be underfitting.

# %% [markdown]
# ## Exercise 2 - Congressional Voting Data
#
# In the attached dataset, results from congressional voting can be found. Your task is to train a model that can recognize that the politician is *republican* or *democrat* based on voting results. We would follow the general machine learning steps that were described in the lecture.

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Loading dataset

# %% [markdown]
# **First mount your google drive to google colab file.**

# %%
path_to_dataset = "voting_complete.csv"
pd_dataset = pd.read_csv(path_to_dataset)

# %%
print(pd_dataset.info())
print(pd_dataset.describe())
pd_dataset.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              435 non-null    int64
#  1   Class Name                              435 non-null    object
#  2   handicapped-infants                     435 non-null    object
#  3   water-project-cost-sharing              435 non-null    object
#  4   adoption-of-the-budget-resolution       435 non-null    object
#  5   physician-fee-freeze                    435 non-null    object
#  6   el-salvador-aid                         435 non-null    object
#  7   religious-groups-in-schools             435 non-null    object
#  8   anti-satellite-test-ban                 435 non-null    object
#  9   aid-to-nicaraguan-contras               435 non-null    object
#  10  mx-missile                              435 non-null    object
#  11  immigration                             435 non-null    object
#  12  synfuels-corporation-cutback            435 non-null    object
#  13  education-spending                      435 non-null    object
#  14  superfund-right-to-sue                  435 non-null    object
#  15  crime                                   435 non-null    object
#  16  duty-free-exports                       435 non-null    object
#  17  export-administration-act-south-africa  435 non-null    object
# dtypes: int64(1), object(17)
# memory usage: 61.3+ KB
# None
#        Unnamed: 0
# count  435.000000
# mean   217.000000
# std    125.717938
# min      0.000000
# 25%    108.500000
# 50%    217.000000
# 75%    325.500000
# max    434.000000
#    Unnamed: 0  Class Name handicapped-infants water-project-cost-sharing  \
# 0           0  republican                   n                          y
# 1           1  republican                   n                          y
# 2           2    democrat                   ?                          y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                    ?               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# 1                           y                       n
# 2                           y                       n
#
#   aid-to-nicaraguan-contras mx-missile immigration  \
# 0                         n          n           y
# 1                         n          n           n
# 2                         n          n           n
#
#   synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                            ?                  y                      y
# 1                            n                  y                      y
# 2                            y                  n                      y
#
#   crime duty-free-exports export-administration-act-south-africa
# 0     y                 n                                      y
# 1     y                 n                                      ?
# 2     y                 n                                      n

# %% [markdown]
# ### 2. Train/Test Split

# %% [markdown]
# Fistlty we need to split our dataset into train and test. We will use 80% of dataset as our trainset and 20% od dataset as our testset. You can use functions included in *keras*, *scikit-learn*, or you can write your own:

# %%
# define a function for train and test split

def train_test_split(pd_data: pd.DataFrame, test_ratio: float = 0.2) -> tuple:
    pd_dataset = pd_data.copy()
    pd_dataset = pd_dataset[pd_dataset.columns[1:]]
    index = np.arange(len(pd_dataset))
    index = np.random.permutation(index)
    train_ammount = int(len(index)*test_ratio)
    train_ids = index[train_ammount:]
    test_ids = index[:train_ammount]

    train_dataset = pd_dataset[pd_dataset.index.isin(train_ids)].reset_index()
    test_dataset = pd_dataset[pd_dataset.index.isin(test_ids)].reset_index()

    train_dataset = train_dataset[train_dataset.columns[1:]]
    test_dataset = test_dataset[test_dataset.columns[1:]]

    return train_dataset[train_dataset.columns[1:]], train_dataset[train_dataset.columns[0]], test_dataset[test_dataset.columns[1:]], test_dataset[test_dataset.columns[0]]

# %%
x_train, y_train, x_test, y_test = train_test_split(pd_dataset)

# %% [markdown]
# ### 3. Data examination

# %% [markdown]
# The task would be to examine the dataset. Check:
#
# 1. Is it a classification of regression task?
# 2. How many data samples do we have?
# 3. How many features do we have?
# 4. What data types do we have in our dataset?
# 5. Are there any missing values?
# 6. How many labels do we have?

# %% [markdown]
# 1. classification task
# 2. 435 data samples
# 3. 16 features because to classify we won't use the class name and the unnamed feature (first two columns)
# 4. boolean variable (yes or no)
# 5. yes
# 6. 2 (republican or democrat)

# %%
x_train
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     ?                          y
# 1                     y                          y
# 2                     n                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 343                   y                          n
# 344                   n                          n
# 345                   n                          n
# 346                   n                          n
# 347                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   y                    ?               y
# 1                                   y                    n               y
# 2                                   n                    y               y
# 3                                   n                    y               y
# 4                                   y                    n               n
# ..                                ...                  ...             ...
# 343                                 y                    n               ?
# 344                                 y                    y               y
# 345                                 y                    n               n
# 346                                 n                    y               y
# 347                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             n                       y
# ..                          ...                     ...
# 343                           n                       y
# 344                           y                       n
# 345                           n                       y
# 346                           y                       ?
# 347                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           n
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           y          y           n
# ..                        ...        ...         ...
# 343                         y          y           y
# 344                         n          y           y
# 345                         y          y           y
# 346                         ?          ?           ?
# 347                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              y                  n                      y
# 1                              y                  ?                      y
# 2                              n                  n                      y
# 3                              n                  y                      y
# 4                              n                  n                      n
# ..                           ...                ...                    ...
# 343                            n                  y                      n
# 344                            n                  y                      y
# 345                            n                  n                      n
# 346                            n                  y                      y
# 347                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      n
# 1       y                 y                                      y
# 2       y                 ?                                      y
# 3       y                 n                                      y
# 4       n                 ?                                      ?
# ..    ...               ...                                    ...
# 343     ?                 y                                      y
# 344     y                 n                                      y
# 345     n                 n                                      y
# 346     y                 n                                      y
# 347     y                 ?                                      n
#
# [348 rows x 16 columns]

# %% [markdown]
# ### 4. Data preprocessing

# %% [markdown]
# When you preprocess your traing data, do not forget that you need to apply the same preprocessing also for your test set. For example: If you decide to delete some columns in your train set, you have to delete the same columns in your test set.

# %% [markdown]
# Possible preprocessing steps (try several and see the influence of your preprocessing on your results)
#  - Replace missing values with any data imputation technique ( for example, the most occurring value in the column), then perform one-hot encoding or label encoding of your data
#  - Consider the missing value to be the third category 'unknown' and then perform one-hot encoding or label encoding
#
# The target value also has to be encoded. This can be done by one-hot encoding or label encoding.

# %%
#fill NaN values with the mode of each column (the most frequent value)
#Replace "?" with NaN
x_train.replace("?", np.nan, inplace=True)
x_train.fillna(x_train.mode().iloc[0], inplace=True)
x_train

#perform one-hot encoding
x=pd.get_dummies(x_train)
x
# Out:
#      handicapped-infants_n  handicapped-infants_y  \
# 0                     True                  False
# 1                    False                   True
# 2                     True                  False
# 3                     True                  False
# 4                    False                   True
# ..                     ...                    ...
# 343                  False                   True
# 344                   True                  False
# 345                   True                  False
# 346                   True                  False
# 347                   True                  False
#
#      water-project-cost-sharing_n  water-project-cost-sharing_y  \
# 0                           False                          True
# 1                           False                          True
# 2                           False                          True
# 3                           False                          True
# 4                           False                          True
# ..                            ...                           ...
# 343                          True                         False
# 344                          True                         False
# 345                          True                         False
# 346                          True                         False
# 347                         False                          True
#
#      adoption-of-the-budget-resolution_n  adoption-of-the-budget-resolution_y  \
# 0                                  False                                 True
# 1                                  False                                 True
# 2                                   True                                False
# 3                                   True                                False
# 4                                  False                                 True
# ..                                   ...                                  ...
# 343                                False                                 True
# 344                                False                                 True
# 345                                False                                 True
# 346                                 True                                False
# 347                                 True                                False
#
#      physician-fee-freeze_n  physician-fee-freeze_y  el-salvador-aid_n  \
# 0                      True                   False              False
# 1                      True                   False              False
# 2                     False                    True              False
# 3                     False                    True              False
# 4                      True                   False               True
# ..                      ...                     ...                ...
# 343                    True                   False               True
# 344                   False                    True              False
# 345                    True                   False               True
# 346                   False                    True              False
# 347                   False                    True              False
#
#      el-salvador-aid_y  ...  education-spending_n  education-spending_y  \
# 0                 True  ...                  True                 False
# 1                 True  ...                  True                 False
# 2                 True  ...                  True                 False
# 3                 True  ...                 False                  True
# 4                False  ...                  True                 False
# ..                 ...  ...                   ...                   ...
# 343              False  ...                 False                  True
# 344               True  ...                 False                  True
# 345              False  ...                  True                 False
# 346               True  ...                 False                  True
# 347               True  ...                 False                  True
#
#      superfund-right-to-sue_n  superfund-right-to-sue_y  crime_n  crime_y  \
# 0                       False                      True    False     True
# 1                       False                      True    False     True
# 2                       False                      True    False     True
# 3                       False                      True    False     True
# 4                        True                     False     True    False
# ..                        ...                       ...      ...      ...
# 343                      True                     False    False     True
# 344                     False                      True    False     True
# 345                      True                     False     True    False
# 346                     False                      True    False     True
# 347                     False                      True    False     True
#
#      duty-free-exports_n  duty-free-exports_y  \
# 0                   True                False
# 1                  False                 True
# 2                   True                False
# 3                   True                False
# 4                   True                False
# ..                   ...                  ...
# 343                False                 True
# 344                 True                False
# 345                 True                False
# 346                 True                False
# 347                 True                False
#
#      export-administration-act-south-africa_n  \
# 0                                        True
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 343                                     False
# 344                                     False
# 345                                     False
# 346                                     False
# 347                                      True
#
#      export-administration-act-south-africa_y
# 0                                       False
# 1                                        True
# 2                                        True
# 3                                        True
# 4                                        True
# ..                                        ...
# 343                                      True
# 344                                      True
# 345                                      True
# 346                                      True
# 347                                     False
#
# [348 rows x 32 columns]

# %%
y=y_train.replace({'republican':1, 'democrat':0})
y
# Out:
# <ipython-input-35-fb296db9e508>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y=y_train.replace({'republican':1, 'democrat':0})
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 343    0
# 344    1
# 345    0
# 346    1
# 347    1
# Name: Class Name, Length: 348, dtype: int64

# %% [markdown]
# ### 5. Creating the model

# %% [markdown]
# 1. Create your model using alteast one hidden layer.
#
# *hint: do not create too complex models, this is a very simple task, so it would be enought to use just few neurons in the hidden layers*

# %%
# WRITE YOU CODE HERE
model = Sequential()
model.add(Dense(8, input_shape=(x.shape[1],), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 2. Check what *model.summary()* does

# %%
# WRITE YOU CODE HERE
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 273 (1.07 KB)
#  Trainable params: 273 (1.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Compile the model, choose a suitable loss function, choose gradient to descend optimizer and specify the learning rate, and choose accuracy as our metric

# %%
# WRITE YOUR CODE HERE
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
#optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %% [markdown]
# 4. Train the model. Specify the number of epochs and batch size. Now is the time to create a validation dataset. Set 20% of dataset to be a validation dataset

# %%
#WRITE YOUR CODE HERE
from sklearn.model_selection import train_test_split

#split the dataset into training and validation dataset (80% training, 20% validation)
X_train, X_val, y_train, y_val=train_test_split(x,y,test_size=0.2)

#train the model with specified epochs and batch size, including validation data
history = model.fit(X_train, y_train,
                    epochs=20, #Number of epochs
                    batch_size=4,
                    verbose=1,
                    validation_data=[X_val,y_val])
# Out:
# Epoch 1/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8289 - loss: 0.3293 - val_accuracy: 0.9571 - val_loss: 0.1515
# Epoch 2/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9550 - loss: 0.1399 - val_accuracy: 0.9143 - val_loss: 0.2253
# Epoch 3/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9699 - loss: 0.1077 - val_accuracy: 0.9571 - val_loss: 0.1529
# Epoch 4/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9582 - loss: 0.0989 - val_accuracy: 0.9571 - val_loss: 0.1477
# Epoch 5/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9742 - loss: 0.0416 - val_accuracy: 0.9714 - val_loss: 0.1316
# Epoch 6/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9768 - loss: 0.0687 - val_accuracy: 0.9571 - val_loss: 0.1505
# Epoch 7/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9733 - loss: 0.0658 - val_accuracy: 0.9714 - val_loss: 0.1348
# Epoch 8/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9706 - loss: 0.0638 - val_accuracy: 0.9714 - val_loss: 0.1386
# Epoch 9/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.0608 - val_accuracy: 0.9714 - val_loss: 0.1789
# Epoch 10/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.0328 - val_accuracy: 0.9286 - val_loss: 0.2015
# Epoch 11/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0526 - val_accuracy: 0.9571 - val_loss: 0.2513
# Epoch 12/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9717 - loss: 0.0586 - val_accuracy: 0.9714 - val_loss: 0.2711
# Epoch 13/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9927 - loss: 0.0308 - val_accuracy: 0.9571 - val_loss: 0.2246
# Epoch 14/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9886 - loss: 0.0256 - val_accuracy: 0.9571 - val_loss: 0.3664
# Epoch 15/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9719 - loss: 0.0650 - val_accuracy: 0.9714 - val_loss: 0.2718
# Epoch 16/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9917 - loss: 0.0233 - val_accuracy: 0.9571 - val_loss: 0.2748
# Epoch 17/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9908 - loss: 0.0282 - val_accuracy: 0.9571 - val_loss: 0.2240
# Epoch 18/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9727 - loss: 0.0453 - val_accuracy: 0.9571 - val_loss: 0.2839
# Epoch 19/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9969 - loss: 0.0169 - val_accuracy: 0.9571 - val_loss: 0.2616
# Epoch 20/20
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.0176 - val_accuracy: 0.9857 - val_loss: 0.2291

# %% [markdown]
# ### 7. Model Evaluation

# %% [markdown]
# 1. First, apply the same preprocessing you did to train set to test set also

# %%
#fill NaN values with the mode of each column (the most frequent value)
#Replace "?" with NaN
x_test.replace("?", np.nan, inplace=True)
x_test.fillna(x_test.mode().iloc[0], inplace=True)
#x_test

#perform one-hot encoding
x_te=pd.get_dummies(x_test)
x_te
y_te=y_test.replace({'republican':1, 'democrat':0})
y_te
# Out:
# <ipython-input-40-d754a979b2e4>:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_te=y_test.replace({'republican':1, 'democrat':0})
# 0     1
# 1     1
# 2     0
# 3     0
# 4     0
#      ..
# 82    0
# 83    0
# 84    0
# 85    0
# 86    1
# Name: Class Name, Length: 87, dtype: int64

# %% [markdown]
# 2. Evaluate the model, print final accuracy and loss

# %%
# WRITE YOUR CODE HERE
loss, accuracy = model.evaluate(x_te, y_te, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
print('Loss: {:.2f}'.format(loss*100))
# Out:
# Accuracy: 94.25
# Loss: 33.32

# %% [markdown]
# 3. Plot loss and validation loss depending on the training epochs into one graph. In another graph, plot accuracy and validation accuracy

# %%
# WRITE YOUR CODE HERE
fig, ax = plt.subplots()
ax.plot(history.history['loss'], label='Training Loss')
ax.plot(history.history['val_loss'], label='Validation Loss')
ax.set_ylabel('Value')
ax.set_xlabel('Epoch')
ax.set_title('Model Loss over Epochs')
ax.legend()
plt.show()

fig, ay = plt.subplots()
ay.plot(history.history['accuracy'], label='Training Accuracy')
ay.plot(history.history['val_accuracy'], label='Validation Accuracy')
ay.set_ylabel('Value')
ay.set_xlabel('Epoch')
ay.set_title('Model Accuracy over Epochs')
ay.legend()
plt.show()
